# %% [markdown]
# ## CLASS: Visualization with Pandas (and Matplotlib)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# read in the drinks data
drink_cols = ['country', 'beer', 'spirit', 'wine', 'liters', 'continent']
drinks = pd.read_csv('data/drinks.csv', header=0, names=drink_cols, na_filter=False)

# %%
drinks
# Out:
#                   country  beer  spirit  wine  liters continent
# 0             Afghanistan     0       0     0     0.0        AS
# 1                 Albania    89     132    54     4.9        EU
# 2                 Algeria    25       0    14     0.7        AF
# 3                 Andorra   245     138   312    12.4        EU
# 4                  Angola   217      57    45     5.9        AF
# 5       Antigua & Barbuda   102     128    45     4.9        NA
# 6               Argentina   193      25   221     8.3        SA
# 7                 Armenia    21     179    11     3.8        EU
# 8               Australia   261      72   212    10.4        OC
# 9                 Austria   279      75   191     9.7        EU
# 10             Azerbaijan    21      46     5     1.3        EU
# 11                Bahamas   122     176    51     6.3        NA
# 12                Bahrain    42      63     7     2.0        AS
# 13             Bangladesh     0       0     0     0.0        AS
# 14               Barbados   143     173    36     6.3        NA
# 15                Belarus   142     373    42    14.4        EU
# 16                Belgium   295      84   212    10.5        EU
# 17                 Belize   263     114     8     6.8        NA
# 18                  Benin    34       4    13     1.1        AF
# 19                 Bhutan    23       0     0     0.4        AS
# 20                Bolivia   167      41     8     3.8        SA
# 21     Bosnia-Herzegovina    76     173     8     4.6        EU
# 22               Botswana   173      35    35     5.4        AF
# 23                 Brazil   245     145    16     7.2        SA
# 24                 Brunei    31       2     1     0.6        AS
# 25               Bulgaria   231     252    94    10.3        EU
# 26           Burkina Faso    25       7     7     4.3        AF
# 27                Burundi    88       0     0     6.3        AF
# 28          Cote d'Ivoire    37       1     7     4.0        AF
# 29             Cabo Verde   144      56    16     4.0        AF
# ..                    ...   ...     ...   ...     ...       ...
# 163              Suriname   128     178     7     5.6        SA
# 164             Swaziland    90       2     2     4.7        AF
# 165                Sweden   152      60   186     7.2        EU
# 166           Switzerland   185     100   280    10.2        EU
# 167                 Syria     5      35    16     1.0        AS
# 168            Tajikistan     2      15     0     0.3        AS
# 169              Thailand    99     258     1     6.4        AS
# 170             Macedonia   106      27    86     3.9        EU
# 171           Timor-Leste     1       1     4     0.1        AS
# 172                  Togo    36       2    19     1.3        AF
# 173                 Tonga    36      21     5     1.1        OC
# 174     Trinidad & Tobago   197     156     7     6.4        NA
# 175               Tunisia    51       3    20     1.3        AF
# 176                Turkey    51      22     7     1.4        AS
# 177          Turkmenistan    19      71    32     2.2        AS
# 178                Tuvalu     6      41     9     1.0        OC
# 179                Uganda    45       9     0     8.3        AF
# 180               Ukraine   206     237    45     8.9        EU
# 181  United Arab Emirates    16     135     5     2.8        AS
# 182        United Kingdom   219     126   195    10.4        EU
# 183              Tanzania    36       6     1     5.7        AF
# 184                   USA   249     158    84     8.7        NA
# 185               Uruguay   115      35   220     6.6        SA
# 186            Uzbekistan    25     101     8     2.4        AS
# 187               Vanuatu    21      18    11     0.9        OC
# 188             Venezuela   333     100     3     7.7        SA
# 189               Vietnam   111       2     1     2.0        AS
# 190                 Yemen     6       0     0     0.1        AS
# 191                Zambia    32      19     4     2.5        AF
# 192              Zimbabwe    64      18     4     4.7        AF
#
# [193 rows x 6 columns]

# %%
# sort the beer column and split it into 3 groups
drinks.sort_values(by=['beer'])
# Out:
#                 country  beer  spirit  wine  liters continent
# 0           Afghanistan     0       0     0     0.0        AS
# 40         Cook Islands     0     254    74     5.9        OC
# 79                 Iran     0       0     0     0.0        AS
# 90               Kuwait     0       0     0     0.0        AS
# 97                Libya     0       0     0     0.0        AF
# 103            Maldives     0       0     0     0.0        AS
# 106    Marshall Islands     0       0     0     0.0        OC
# 111              Monaco     0       0     0     0.0        EU
# 128            Pakistan     0       0     0     0.0        AS
# 147          San Marino     0       0     0     0.0        EU
# 13           Bangladesh     0       0     0     0.0        AS
# 149        Saudi Arabia     0       5     0     0.1        AS
# 107          Mauritania     0       0     0     0.0        AF
# 158             Somalia     0       0     0     0.0        AF
# 46          North Korea     0       0     0     0.0        AS
# 137               Qatar     1      42     7     0.9        AS
# 38              Comoros     1       3     1     0.1        AF
# 171         Timor-Leste     1       1     4     0.1        AS
# 73                Haiti     1     326     1     5.9        NA
# 168          Tajikistan     2      15     0     0.3        AS
# 123               Niger     3       2     1     0.1        AF
# 119               Nepal     5       6     0     0.2        AS
# 116             Myanmar     5       1     0     0.1        AS
# 167               Syria     5      35    16     1.0        AS
# 104                Mali     5       1     1     0.6        AF
# 78            Indonesia     5       1     0     0.1        AS
# 53                Egypt     6       4     1     0.2        AF
# 190               Yemen     6       0     0     0.1        AS
# 86               Jordan     6      21     1     0.5        AS
# 178              Tuvalu     6      41     9     1.0        OC
# ..                  ...   ...     ...   ...     ...       ...
# 76              Iceland   233      61    78     6.6        EU
# 75              Hungary   234     215   185    11.3        EU
# 99           Luxembourg   236     133   271    11.4        EU
# 109              Mexico   238      68     5     5.5        NA
# 32               Canada   240     122   100     8.2        NA
# 3               Andorra   245     138   312    12.4        EU
# 23               Brazil   245     145    16     7.2        SA
# 141  Russian Federation   247     326    73    11.5        AS
# 184                 USA   249     158    84     8.7        NA
# 120         Netherlands   251      88   190     9.4        EU
# 8             Australia   261      72   212    10.4        OC
# 60              Finland   263     133    97    10.0        EU
# 17               Belize   263     114     8     6.8        NA
# 156            Slovenia   270      51   276    10.6        EU
# 9               Austria   279      75   191     9.7        EU
# 93               Latvia   281     216    62    10.5        EU
# 151              Serbia   283     131   127     9.6        EU
# 160               Spain   284     157   112    10.0        EU
# 130              Panama   285     104    18     7.2        NA
# 16              Belgium   295      84   212    10.5        EU
# 140             Romania   297     122   167    10.4        EU
# 129               Palau   306      63    23     6.9        OC
# 81              Ireland   313     118   165    11.4        EU
# 188           Venezuela   333     100     3     7.7        SA
# 98            Lithuania   343     244    56    12.9        EU
# 135              Poland   343     215    56    10.9        EU
# 65              Germany   346     117   175    11.3        EU
# 62                Gabon   347      98    59     8.9        AF
# 45       Czech Republic   361     170   134    11.8        EU
# 117             Namibia   376       3     1     6.8        AF
#
# [193 rows x 6 columns]

# %%
drinks
# Out:
#                   country  beer  spirit  wine  liters continent
# 0             Afghanistan     0       0     0     0.0        AS
# 1                 Albania    89     132    54     4.9        EU
# 2                 Algeria    25       0    14     0.7        AF
# 3                 Andorra   245     138   312    12.4        EU
# 4                  Angola   217      57    45     5.9        AF
# 5       Antigua & Barbuda   102     128    45     4.9        NA
# 6               Argentina   193      25   221     8.3        SA
# 7                 Armenia    21     179    11     3.8        EU
# 8               Australia   261      72   212    10.4        OC
# 9                 Austria   279      75   191     9.7        EU
# 10             Azerbaijan    21      46     5     1.3        EU
# 11                Bahamas   122     176    51     6.3        NA
# 12                Bahrain    42      63     7     2.0        AS
# 13             Bangladesh     0       0     0     0.0        AS
# 14               Barbados   143     173    36     6.3        NA
# 15                Belarus   142     373    42    14.4        EU
# 16                Belgium   295      84   212    10.5        EU
# 17                 Belize   263     114     8     6.8        NA
# 18                  Benin    34       4    13     1.1        AF
# 19                 Bhutan    23       0     0     0.4        AS
# 20                Bolivia   167      41     8     3.8        SA
# 21     Bosnia-Herzegovina    76     173     8     4.6        EU
# 22               Botswana   173      35    35     5.4        AF
# 23                 Brazil   245     145    16     7.2        SA
# 24                 Brunei    31       2     1     0.6        AS
# 25               Bulgaria   231     252    94    10.3        EU
# 26           Burkina Faso    25       7     7     4.3        AF
# 27                Burundi    88       0     0     6.3        AF
# 28          Cote d'Ivoire    37       1     7     4.0        AF
# 29             Cabo Verde   144      56    16     4.0        AF
# ..                    ...   ...     ...   ...     ...       ...
# 163              Suriname   128     178     7     5.6        SA
# 164             Swaziland    90       2     2     4.7        AF
# 165                Sweden   152      60   186     7.2        EU
# 166           Switzerland   185     100   280    10.2        EU
# 167                 Syria     5      35    16     1.0        AS
# 168            Tajikistan     2      15     0     0.3        AS
# 169              Thailand    99     258     1     6.4        AS
# 170             Macedonia   106      27    86     3.9        EU
# 171           Timor-Leste     1       1     4     0.1        AS
# 172                  Togo    36       2    19     1.3        AF
# 173                 Tonga    36      21     5     1.1        OC
# 174     Trinidad & Tobago   197     156     7     6.4        NA
# 175               Tunisia    51       3    20     1.3        AF
# 176                Turkey    51      22     7     1.4        AS
# 177          Turkmenistan    19      71    32     2.2        AS
# 178                Tuvalu     6      41     9     1.0        OC
# 179                Uganda    45       9     0     8.3        AF
# 180               Ukraine   206     237    45     8.9        EU
# 181  United Arab Emirates    16     135     5     2.8        AS
# 182        United Kingdom   219     126   195    10.4        EU
# 183              Tanzania    36       6     1     5.7        AF
# 184                   USA   249     158    84     8.7        NA
# 185               Uruguay   115      35   220     6.6        SA
# 186            Uzbekistan    25     101     8     2.4        AS
# 187               Vanuatu    21      18    11     0.9        OC
# 188             Venezuela   333     100     3     7.7        SA
# 189               Vietnam   111       2     1     2.0        AS
# 190                 Yemen     6       0     0     0.1        AS
# 191                Zambia    32      19     4     2.5        AF
# 192              Zimbabwe    64      18     4     4.7        AF
#
# [193 rows x 6 columns]

# %% [markdown]
# ### Histogram: show the distribution of a numerical variable

# %%
# compare with histogram
drinks.beer.plot(kind='hist', bins=3)

# %%
# try more bins
drinks.beer.plot(kind='hist', bins=20)

# %%
# add title and labels
drinks.beer.plot(kind='hist', bins=20, title='Histogram of Beer Servings')
plt.xlabel('Beer Servings')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
# compare with density plot (smooth version of a histogram)
drinks.beer.plot(kind='density', xlim=(0, 500))

# %%
# stacked histogram with multiple variables
drinks[['beer', 'spirit', 'wine']].plot(kind='hist', stacked=True)

# %% [markdown]
# ### Scatter Plot: show the relationship between two numerical variables

# %%
# select the beer and wine columns and sort by beer
# drinks[['beer', 'wine']].sort('beer').values
drinks.sort_values(by=['beer','wine'])
# Out:
#                 country  beer  spirit  wine  liters continent
# 0           Afghanistan     0       0     0     0.0        AS
# 13           Bangladesh     0       0     0     0.0        AS
# 46          North Korea     0       0     0     0.0        AS
# 79                 Iran     0       0     0     0.0        AS
# 90               Kuwait     0       0     0     0.0        AS
# 97                Libya     0       0     0     0.0        AF
# 103            Maldives     0       0     0     0.0        AS
# 106    Marshall Islands     0       0     0     0.0        OC
# 107          Mauritania     0       0     0     0.0        AF
# 111              Monaco     0       0     0     0.0        EU
# 128            Pakistan     0       0     0     0.0        AS
# 147          San Marino     0       0     0     0.0        EU
# 149        Saudi Arabia     0       5     0     0.1        AS
# 158             Somalia     0       0     0     0.0        AF
# 40         Cook Islands     0     254    74     5.9        OC
# 38              Comoros     1       3     1     0.1        AF
# 73                Haiti     1     326     1     5.9        NA
# 171         Timor-Leste     1       1     4     0.1        AS
# 137               Qatar     1      42     7     0.9        AS
# 168          Tajikistan     2      15     0     0.3        AS
# 123               Niger     3       2     1     0.1        AF
# 78            Indonesia     5       1     0     0.1        AS
# 116             Myanmar     5       1     0     0.1        AS
# 119               Nepal     5       6     0     0.2        AS
# 104                Mali     5       1     1     0.6        AF
# 167               Syria     5      35    16     1.0        AS
# 190               Yemen     6       0     0     0.1        AS
# 53                Egypt     6       4     1     0.2        AF
# 86               Jordan     6      21     1     0.5        AS
# 178              Tuvalu     6      41     9     1.0        OC
# ..                  ...   ...     ...   ...     ...       ...
# 76              Iceland   233      61    78     6.6        EU
# 75              Hungary   234     215   185    11.3        EU
# 99           Luxembourg   236     133   271    11.4        EU
# 109              Mexico   238      68     5     5.5        NA
# 32               Canada   240     122   100     8.2        NA
# 23               Brazil   245     145    16     7.2        SA
# 3               Andorra   245     138   312    12.4        EU
# 141  Russian Federation   247     326    73    11.5        AS
# 184                 USA   249     158    84     8.7        NA
# 120         Netherlands   251      88   190     9.4        EU
# 8             Australia   261      72   212    10.4        OC
# 17               Belize   263     114     8     6.8        NA
# 60              Finland   263     133    97    10.0        EU
# 156            Slovenia   270      51   276    10.6        EU
# 9               Austria   279      75   191     9.7        EU
# 93               Latvia   281     216    62    10.5        EU
# 151              Serbia   283     131   127     9.6        EU
# 160               Spain   284     157   112    10.0        EU
# 130              Panama   285     104    18     7.2        NA
# 16              Belgium   295      84   212    10.5        EU
# 140             Romania   297     122   167    10.4        EU
# 129               Palau   306      63    23     6.9        OC
# 81              Ireland   313     118   165    11.4        EU
# 188           Venezuela   333     100     3     7.7        SA
# 98            Lithuania   343     244    56    12.9        EU
# 135              Poland   343     215    56    10.9        EU
# 65              Germany   346     117   175    11.3        EU
# 62                Gabon   347      98    59     8.9        AF
# 45       Czech Republic   361     170   134    11.8        EU
# 117             Namibia   376       3     1     6.8        AF
#
# [193 rows x 6 columns]

# %%
# compare with scatter plot
drinks.plot(kind='scatter', x='beer', y='wine')

# %%
# add transparency
drinks.plot(kind='scatter', x='beer', y='wine', alpha=0.3)

# %%
# vary point color by spirit servings
drinks.plot(kind='scatter', x='beer', y='wine', c='spirit', colormap='Blues')

# %%
# scatter matrix of three numerical columns
pd.scatter_matrix(drinks[['beer', 'spirit', 'wine']])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.scatter_matrix is deprecated, use pandas.plotting.scatter_matrix instead
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000000B3519E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000B37A710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000B3A2C88>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000000B3D1240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000B3FC7B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000B422E80>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000000B4542B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000B47C860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000B47C898>]],
#       dtype=object)

# %%
# increase figure size
pd.scatter_matrix(drinks[['beer', 'spirit', 'wine']], figsize=(10, 8))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.scatter_matrix is deprecated, use pandas.plotting.scatter_matrix instead
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000000B5767F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000B5D5C18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000000090851D0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000000090AC748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000000090D5C88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000009105240>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000000912D7B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000009155D68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000009155DA0>]],
#       dtype=object)

# %% [markdown]
# ### Bar Plot: show a numerical comparison across different categories

# %%
# count the number of countries in each continent
drinks.continent.value_counts()
# Out:
# AF    53
# EU    45
# AS    44
# NA    23
# OC    16
# SA    12
# Name: continent, dtype: int64

# %%
# compare with bar plot
drinks.continent.value_counts().plot(kind='bar')

# %%
# calculate the average beer/spirit/wine amounts for each continent
drinks.groupby('continent').mean().drop('liters', axis=1)
# Out:
#                  beer      spirit        wine
# continent
# AF          61.471698   16.339623   16.264151
# AS          37.045455   60.840909    9.068182
# EU         193.777778  132.555556  142.222222
# NA         145.434783  165.739130   24.521739
# OC          89.687500   58.437500   35.625000
# SA         175.083333  114.750000   62.416667

# %%
# side-by-side bar plots
drinks.groupby('continent').mean().drop('liters', axis=1).plot(kind='bar')

# %%
# stacked bar plots
drinks.groupby('continent').mean().drop('liters', axis=1).plot(kind='bar', stacked=True)

# %% [markdown]
# ### Box Plot: show quartiles (and outliers) for one or more numerical variables

# %%
# show "five-number summary" for beer
drinks.beer.describe()
# Out:
# count    193.000000
# mean     106.160622
# std      101.143103
# min        0.000000
# 25%       20.000000
# 50%       76.000000
# 75%      188.000000
# max      376.000000
# Name: beer, dtype: float64

# %%
# compare with box plot
drinks.beer.plot(kind='box')

# %%
# include multiple variables
drinks.drop('liters', axis=1).plot(kind='box')

# %% [markdown]
# ### Line Plot: show the trend of a numerical variable over time

# %%
# read in the ufo data
ufo = pd.read_csv(r'data\ufo.csv')
ufo['Time'] = pd.to_datetime(ufo.Time)
ufo['Year'] = ufo.Time.dt.year

# %%
# count the number of ufo reports each year (and sort by year)
ufo.Year.value_counts().sort_index()
# Out:
# 1930       2
# 1931       2
# 1933       1
# 1934       1
# 1935       1
# 1936       2
# 1937       2
# 1939       3
# 1941       2
# 1942       3
# 1943       5
# 1944       8
# 1945       9
# 1946       8
# 1947      41
# 1948       9
# 1949      19
# 1950      31
# 1951      21
# 1952      52
# 1953      36
# 1954      55
# 1955      33
# 1956      46
# 1957      78
# 1958      53
# 1959      57
# 1960      67
# 1961      50
# 1962      72
#         ...
# 1985     211
# 1986     186
# 1987     210
# 1988     232
# 1989     247
# 1990     237
# 1991     220
# 1992     245
# 1993     292
# 1994     406
# 1995    1344
# 1996     851
# 1997    1237
# 1998    1743
# 1999    2774
# 2000    2635
# 2001    2925
# 2002    2933
# 2003    3507
# 2004    3850
# 2005    3787
# 2006    3445
# 2007    4058
# 2008    4655
# 2009    4251
# 2010    4154
# 2011    5089
# 2012    7263
# 2013    7003
# 2014    5382
# Name: Year, Length: 82, dtype: int64

# %%
# compare with line plot
ufo.Year.value_counts().sort_index().plot()

# %%
# don't use a line plot when there is no logical ordering
drinks.continent.value_counts().plot()

# %% [markdown]
# ### Grouped Box Plots and Grouped Histograms: show one plot for each group

# %%
# reminder: box plot of beer servings
drinks.beer.plot(kind='box')

# %%
# reminder: histogram of beer servings
drinks.beer.plot(kind='hist')

# %%
# box plot of beer servings grouped by continent
drinks.boxplot(column='beer', by='continent')

# %%
# histogram of beer servings grouped by continent
drinks.beer.hist(by=drinks.continent)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000000C020CC0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000C046F98>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000000C077240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000C0A04A8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000000C0C7940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000D531EB8>]],
#       dtype=object)

# %%
# share the x axes
drinks.beer.hist(by=drinks.continent, sharex=True)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000000D675A58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000D69D6D8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000000D6C5C18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000D6F40B8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000000D71C518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000D745978>]],
#       dtype=object)

# %%
# share the x and y axes
drinks.beer.hist(by=drinks.continent, sharex=True, sharey=True)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000000D8116A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000D90B5C0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000000D92F898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000D957B70>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000000D980E48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000D9B1160>]],
#       dtype=object)

# %%
# change the layout
drinks.beer.hist(by=drinks.continent, layout=(2, 3))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000000DA6F8D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000DB94C18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000DBBD1D0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000000DBE5748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000DC0DCC0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000DC3D278>]],
#       dtype=object)

# %%
# box plot of all numeric columns grouped by continent
drinks.boxplot(by='continent')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000000DCA64A8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000DDA2A90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000000DDC9D68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000DDFA080>]],
#       dtype=object)

# %% [markdown]
# ### Assorted Functionality

# %%
# saving a plot to a file: run all four lines at once
drinks.beer.plot(kind='hist', bins=20, title='Histogram of Beer Servings')
plt.xlabel('Beer Servings')
plt.ylabel('Frequency')
plt.savefig('beer_histogram.png')

# %%
# list available plot styles
plt.style.available
# Out:
# ['bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark-palette',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'seaborn',
#  'Solarize_Light2',
#  'tableau-colorblind10',
#  '_classic_test']

# %%
# change to a different style
plt.style.use('ggplot')
